# %% [markdown]
# # Setup

# %%
#From CS231n assgn 3 Spring 2018
import os 
import cv2 as cv
import pandas as pd 
from skimage import io,transform
import torch
import torch.nn as nn 
from torch.nn import init
import torchvision
import torchvision.transforms as T
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import sampler
import torchvision.datasets as dset

import numpy as np 

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec 

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0,8.0)
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'


   
# def sample_noise(batch_size,dim):
#     noise = torch.randn((batch_size,dim))
#     noise = noise/torch.max(noise)
#     return noise

#Flatten module from CS231n assign 3 Pytorch-GAN
class Flatten(nn.Module):
    def forward(self,x):
        N,H,W,C = x.size()
        return x.view(N,-1)
    
#Unflatten module from CS231n assign 3 Pytorch-GAN
class Unflatten(nn.Module):
    "Unflattens module receiving (N,C*H*W) and reshapes into (N,H,W,C)"
    def __init__(self,N=-1,H=7,W=7,C=128):
        super(Unflatten,self).__init__()
        self.N = N
        self.C = C 
        self.H = H 
        self.W = W 
    def forward(self,x):
        return x.view(self.N,self.H,self.W,self.C)

#initialize module from CS231n assign 3 Pytorch-GAN
def initialize_weights(m):
    if isinstance(m,nn.Linear) or isinstance(m,nn.ConvTranspose2d):
        init.xavier_uniform(m.weight.data)

# %% [markdown]
# ## Constants

# %%
dtype = torch.cuda.FloatTensor
input_img_size = (419,419,3)
BATCH_SIZE = 16
batch_size = BATCH_SIZE
BRDF_DIM = 21 
image_new_size = (64,64,3)

N = BATCH_SIZE
# H,W,C = input_img_size
H,W,C = image_new_size

# %% [markdown]
# # Data Loading

# %%
brdf_frame = pd.read_table('./train-set/output_empty.txt',delim_whitespace = True,header=None)
n = 999
image_name = str(brdf_frame.iloc[n, 0])

print("image name: {} ".format(image_name))
def show_image(images,brdf): #works on reshaped dataset in C H W order 
    images = np.transpose(images,(1,2,0))
    plt.imshow(images)
    plt.pause(0.001)
# Out:
# image name: 1000

# %%
#from loading data tutorial pytorch: 
#https://pytorch.org/tutorials/beginner/data_loading_tutorial.html
class GMSDataset(Dataset):
    def __init__(self,txt_file,root_dir,transform =None):
        """
        Args: 
            txt_file (string): path to string file with annotations for imgs
            root_dir (string): Directory with imgs
            transform (callable, optional): Optional transform on a sample
        """
        self.brdf_frame = pd.read_table(txt_file, delim_whitespace = True,header=None)
        self.root_dir = root_dir
        self.transform = transform
        
    def __len__(self):
        return len(self.brdf_frame)
    
    def __getitem__(self,idx):
        output_name = 'output' + str(self.brdf_frame.iloc[idx,0]).zfill(7)
        img_name = os.path.join(self.root_dir,
                                output_name+'.png')
        image = io.imread(img_name)
        image = cv.resize(image,(64, 64), interpolation = cv.INTER_AREA)
        image = np.transpose(image,axes = (2,0,1))
        image = torch.from_numpy(image)
        
        brdf = self.brdf_frame.iloc[idx,1:]
        brdf = (torch.from_numpy(brdf.as_matrix())).float()
        sample = {'image': image, 'brdf': brdf}
        if self.transform: 
            sample = self.transform(sample)
        return sample

# %%
sphere_dataset_train = GMSDataset(txt_file = './train-set/output_empty.txt',
                                  root_dir = './train-set')
fig = plt.figure()

for i in range(len(sphere_dataset_train)):
    sample = sphere_dataset_train[i]

    print(i, sample['image'].shape, sample['brdf'].shape)

    ax = plt.subplot(1, 4, i + 1)
    plt.tight_layout()
    ax.set_title('Sample #{}'.format(i))
    ax.axis('off')
    show_image(sample['image'],sample['brdf'])

    if i == 3:
        plt.show()
        break
# Out:
# 0 torch.Size([3, 64, 64]) torch.Size([21])
# /home/arjunarora/anaconda3/envs/cs248/lib/python3.6/site-packages/ipykernel_launcher.py:28: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# 1 torch.Size([3, 64, 64]) torch.Size([21])
# 2 torch.Size([3, 64, 64]) torch.Size([21])
# 3 torch.Size([3, 64, 64]) torch.Size([21])

# %%
sphere_dataset_test = GMSDataset(txt_file = './val-set/output_empty.txt',
                                 root_dir = './val-set')
fig = plt.figure()

for i in range(len(sphere_dataset_test)):
    sample = sphere_dataset_test[i]

    print(i, sample['image'].shape, sample['brdf'].shape)

    ax = plt.subplot(1, 4, i + 1)
    plt.tight_layout()
    ax.set_title('Sample #{}'.format(i))
    ax.axis('off')
    show_image(sample['image'],sample['brdf'])

    if i == 3:
        plt.show()
        break
# Out:
# 0 torch.Size([3, 64, 64]) torch.Size([21])
# /home/arjunarora/anaconda3/envs/cs248/lib/python3.6/site-packages/ipykernel_launcher.py:28: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# 1 torch.Size([3, 64, 64]) torch.Size([21])
# 2 torch.Size([3, 64, 64]) torch.Size([21])
# 3 torch.Size([3, 64, 64]) torch.Size([21])

# %%
def sphere_model_batch(index,batch_size=BATCH_SIZE,train_or_val=True):
#     ""
#     Takes in an index and produces a batch_size of images and brdfs for sphere_dataset_train
#     or sphere_dataset_test
#     ""
    batch_image = None
    batch_brdf = None

    if train_or_val:
        if(index+batch_size >len(sphere_dataset_train)):
            batch_size = len(sphere_dataset_train) - index
            
        batch_image = sphere_dataset_train[index]['image'].unsqueeze(0)
        batch_brdf = sphere_dataset_train[index]['brdf'].unsqueeze(0)
        for i in range(index+1,index+batch_size):
            x = sphere_dataset_train[i]
            batch_image = torch.cat((batch_image,x['image'].unsqueeze(0)),dim=0)
            batch_brdf = torch.cat((batch_brdf,x['brdf'].unsqueeze(0)),dim=0)
    else:
        if(index+batch_size >len(sphere_dataset_test)):
            batch_size = len(sphere_dataset_test) - index
                
        batch_image = sphere_dataset_test[index]['image'].unsqueeze(0)
        batch_brdf = sphere_dataset_test[index]['brdf'].unsqueeze(0)
        for i in range(index,batch_size):
           
            x = sphere_dataset_test[i]
            batch_image = torch.cat((batch_image,x['image'].unsqueeze(0)),dim=0)
            batch_brdf = torch.cat((batch_brdf,x['brdf'].unsqueeze(0)),dim=0)
    return batch_image,batch_brdf
y = sphere_model_batch(956)
print(y[0].shape)
print(y[1].shape)
show_image(y[0][0],y[1][0])
# Out:
# torch.Size([16, 3, 64, 64])
# torch.Size([16, 21])
# /home/arjunarora/anaconda3/envs/cs248/lib/python3.6/site-packages/ipykernel_launcher.py:28: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %% [markdown]
# ## Image Display

# %%
def show_images(images, cols = 1, titles = None):
    """Display a list of images in a single figure with matplotlib.
    
    Parameters
    ---------
    images: List of np.arrays compatible with plt.imshow.
    
    cols (Default = 1): Number of columns in figure (number of rows is 
                        set to np.ceil(n_images/float(cols))).
    
    titles: List of titles corresponding to each image. Must have
            the same length as titles.
    """
    assert((titles is None)or (len(images) == len(titles)))
    n_images = len(images)
    if titles is None: titles = ['Image (%d)' % i for i in range(1,n_images + 1)]
    fig = plt.figure()
    for n, (image, title) in enumerate(zip(images, titles)):
        a = fig.add_subplot(cols, np.ceil(n_images/float(cols)), n + 1)
        if image.ndim == 2:
            plt.gray()
        plt.imshow(image)
        a.set_title(title)
    fig.set_size_inches(np.array(fig.get_size_inches()) * n_images)
    plt.show()

# %% [markdown]
# # Models

# %% [markdown]
# ## Discriminators

# %%
# simple DCGAN derived from cs 231n (see above)
def dc_discriminator():
        model = nn.Sequential(nn.Conv2d(C,                              #output tensor = (N , 64 , 64 , 64)
                                    64,                          
                                    kernel_size = 5,
                                    stride = 1,
                                    padding = 2), 
                              nn.LeakyReLU(0.01),
                              nn.MaxPool2d(kernel_size= 2,stride=2),  #output tensor = (N , 64 , 32 , 32)
                              nn.Conv2d(64,                              #output tensor = (N , 64 , 32 , 32)
                                        64,                          
                                        kernel_size = 5,
                                        stride = 1,
                                        padding = 2), 
                              nn.LeakyReLU(0.01),
                              nn.MaxPool2d(2,stride=2),                 # output tensor = (N , 64 , 16 , 16)
                              nn.Conv2d(64,                             # output tensor = (N , 64 , 16 , 16)
                                        64,                          
                                        kernel_size = 5,
                                        stride = 1,
                                        padding = 2), 
                              nn.LeakyReLU(0.01),
                              nn.MaxPool2d(2,stride=2),                  # output tensor = (N, 64 , 8 , 8)
                              nn.Conv2d(64,                              # output tensor = (N , 64 , 8 , 8)
                                        64,                          
                                        kernel_size = 5,
                                        stride = 1,
                                        padding = 2), 
                              nn.LeakyReLU(0.01),
                              nn.MaxPool2d(2,stride=2),                 # output tensor = (N , 64 , 4 ,4)
                              nn.Conv2d(64,                             # output tensor = (N , 64 , 4 , 4)
                                        64,                          
                                        kernel_size = 5,
                                        stride = 1,
                                        padding = 2), 
                              nn.LeakyReLU(0.01),
                              nn.MaxPool2d(2,stride=2),                 # output tensor = (N , 64, 2 , 2 )
                              Flatten(),
                              nn.Linear(256,256),
                              nn.LeakyReLU(0.01),
                              nn.Linear(256,1)
                )
        return model


test_d_gan = dc_discriminator().type(dtype)
test_d_gan.apply(initialize_weights)

real_seed = torch.randn(BATCH_SIZE,C,H,W).type(dtype)
print("input_size: ",real_seed.shape)
real_images = test_d_gan.forward(real_seed)
print("output_size: ",real_images.shape)
# Out:
# input_size:  torch.Size([16, 3, 64, 64])
# output_size:  torch.Size([16, 1])
# /home/arjunarora/anaconda3/envs/cs248/lib/python3.6/site-packages/ipykernel_launcher.py:54: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.

# %% [markdown]
# ## Generators

# %%
def dc_generator(brdf_dim=BRDF_DIM):
    #simple GAN derived from cs 231n (see above)
#     model = nn.Sequential(nn.Linear(brdf_dim,hidden_size_generator),
#                           nn.ReLU(),
#                           nn.BatchNorm1d(1024),
#                           nn.Linear(hidden_size_generator,7*7*N),
#                           nn.ReLU(),
#                           nn.BatchNorm1d(7*7*N),
#                           Unflatten(-1,N,7,7),
#                           nn.ConvTranspose2d(N,64,128,stride = 2,padding = 1),
#                           nn.ReLU(),
#                           nn.BatchNorm2d(64),
#                           nn.ConvTranspose2d(64,3,147,stride = 2, padding = 1),
#                           nn.Tanh()
    #model derived from GMS paper (too large :c )
#     model = nn.Sequential(nn.Conv1d(1,64,3), # output = (N,64,21)
#                           nn.ELU(),
#                           nn.Upsample(scale_factor = 2), # output = (N,64,42)
#                           nn.Conv1d(64,64,3),            # output = (N,64,42)
#                           nn.ELU(),
#                           nn.Upsample(scale_factor = 2), # output = (N,64,84)
#                           nn.Conv1d(64,64,3),            # output = (N,64,84)
#                           nn.ELU(),
#                           nn.Conv1d(64,64,3),            # output = (N,84,84) 
#                           Unflatten(N,84,84),
#                           nn.MaxPool2d(21,stride = 1) # output = (N,64, 64)
 
#     model = nn.Sequential(nn.Linear(brdf_dim,hidden_size_generator),
#                           nn.ELU(),
#                           nn.BatchNorm1d(hidden_size_generator),
#                           nn.Linear(hidden_size_generator,N * 4 * 4),
#                           nn.ELU(),
#                           nn.BatchNorm1d(N * 4 * 4 ),
#                           Unflatten(-1,N,4,4),
#                           nn.ConvTranspose2d(N,64,4,stride = 2, padding = 1),
#                           nn.ELU(),
#                           nn.BatchNorm2d(64),
#                           nn.ConvTranspose2d(64,64,4,stride = 2 , padding = 1),
#                           nn.ELU(),
#                           nn.BatchNorm2d(64),
#                           nn.ConvTranspose2d(64,64,4,stride = 2 , padding = 1),
#                           nn.ELU(),
#                           nn.BatchNorm2d(64),
#                           nn.ConvTranspose2d(64,3,4,stride = 2, padding = 1),
#                           nn.ELU()
                          
    )
    return model
test_g_gan = dc_generator().type(dtype)
test_g_gan.apply(initialize_weights)

fake_seed = torch.randn(BATCH_SIZE, BRDF_DIM).type(dtype).unsqueeze(1)
print("input size: ",fake_seed.shape)
fake_images = test_g_gan.forward(fake_seed)
print("output_size: ", fake_images.size())
# Out:
# input size:  torch.Size([16, 1, 21])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-109-572239ffbc14> in <module>()
#      52 fake_seed = torch.randn(BATCH_SIZE, BRDF_DIM).type(dtype).unsqueeze(1)
#      53 print("input size: ",fake_seed.shape)
# ---> 54 fake_images = test_g_gan.forward(fake_seed)
#      55 print("output_size: ", fake_images.size())
#
# ~/anaconda3/envs/cs248/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      89     def forward(self, input):
#      90         for module in self._modules.values():
# ---> 91             input = module(input)
#      92         return input
#      93
#
# ~/anaconda3/envs/cs248/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# ...

# %% [markdown]
# # Optimizers and Loss

# %%
def bce_loss(input, target):
    """
    Numerically stable version of the binary cross-entropy loss function.

    As per https://github.com/pytorch/pytorch/issu|es/751
    See the TensorFlow docs for a derivation of this formula:
    https://www.tensorflow.org/api_docs/python/tf/nn/sigmoid_cross_entropy_with_logits

    Inputs:
    - input: PyTorch Tensor of shape (N, ) giving scores.
    - target: PyTorch Tensor of shape (N,) containing 0 and 1 giving targets.

    Returns:
    - A PyTorch Tensor containing the mean BCE loss over the minibatch of input data.
    """
    neg_abs = - input.abs()
    loss = input.clamp(min=0) - input * target + (1 + neg_abs.exp()).log()
    return loss.mean()

# %%
def discriminator_loss(logits_real, logits_fake):
    """
    Computes the discriminator loss described above.
    
    Inputs:
    - logits_real: PyTorch Tensor of shape (N,) giving scores for the real data.
    - logits_fake: PyTorch Tensor of shape (N,) giving scores for the fake data.
    
    Returns:
    - loss: PyTorch Tensor containing (scalar) the loss for the discriminator.
    """
    
    real_labels = torch.ones_like(logits_real)
    fake_labels = torch.zeros_like(logits_fake)
    loss = bce_loss(logits_real,real_labels) + bce_loss(logits_fake,fake_labels)
    return loss

def generator_loss(logits_fake):
    """
    Computes the generator loss described above.

    Inputs:
    - logits_fake: PyTorch Tensor of shape (N,) giving scores for the fake data.
    
    Returns:
    - loss: PyTorch Tensor containing the (scalar) loss for the generator.
    """
    fake_labels = torch.ones_like(logits_fake)
    loss = bce_loss(logits_fake,fake_labels)
    return loss

# %%
def get_optimizer(model):
    """
    Construct and return an Adam optimizer for the model with learning rate 1e-3,
    beta1=0.5, and beta2=0.999.
    
    Input:
    - model: A PyTorch model that we want to optimize.
    
    Returns:
    - An Adam optimizer for the model with the desired hyperparameters.
    """
    
    optimizer = optim.Adam(model.parameters(),lr =1e-3,betas=(0.5,0.999))
    return optimizer

# %%
def ls_discriminator_loss(scores_real, scores_fake):
    """
    Compute the Least-Squares GAN loss for the discriminator.
    
    Inputs:
    - scores_real: PyTorch Tensor of shape (N,) giving scores for the real data.
    - scores_fake: PyTorch Tensor of shape (N,) giving scores for the fake data.
    
    Outputs:
    - loss: A PyTorch Tensor containing the loss.
    """
    
    loss = None
#     real_labels = torch.ones_like(scores_real)
#     fake_labels = torch.zeros_like(scores_fake)
    Dx = scores_real - 1 
    D_gz = scores_fake
    loss = 0.5 * torch.mul(Dx,Dx).mean() + 0.5 * torch.mul(D_gz,D_gz).mean()
    return loss

def ls_generator_loss(scores_fake):
    """
    Computes the Least-Squares GAN loss for the generator.
    
    Inputs:
    - scores_fake: PyTorch Tensor of shape (N,) giving scores for the fake data.
    
    Outputs:
    - loss: A PyTorch Tensor containing the loss.
    """
    D_gz = scores_fake - 1
    loss = 0.5 * torch.mul(D_gz,D_gz).mean()
    return loss

# %% [markdown]
# ## Train GAN

# %%
def run_gan(D,G,D_solver,G_solver,
            discriminator_loss,generator_loss,
            show_every = 100, batch_size = BATCH_SIZE,
            noise_size = 96,num_epochs = 5):

    iter_count = 0
    for epoch in range(num_epochs):
        for i in range(0,len(sphere_dataset_train),batch_size):
            x = sphere_model_batch(i,batch_size=batch_size)
            if x[0].shape[0] != batch_size:
                continue
            D_solver.zero_grad()
            real_data = x[0].type(dtype)
            logits_real = D(2* (real_data - 0.5)).type(dtype)

            g_fake_seed = x[1].type(dtype)
            fake_images = G(g_fake_seed).detach()
            
            logits_fake = D(fake_images)
            
            d_total_error = discriminator_loss(logits_real, logits_fake)
            d_total_error.backward()        
            D_solver.step()

            G_solver.zero_grad()
            g_fake_seed = x[1].type(dtype)
            fake_images = G(g_fake_seed)

            gen_logits_fake = D(fake_images)
            g_error = generator_loss(gen_logits_fake)
            g_error.backward()
            G_solver.step()
            
            if (iter_count % show_every == 0):
                print('Iter: {}, D: {:.4}, G:{:.4}'.format(iter_count,d_total_error.item(),g_error.item()))
                imgs_numpy = fake_images.data.cpu().numpy()
                img_0 = np.transpose(imgs_numpy[0],(1,2,0))
                img_1 = np.transpose(x[0][0].numpy(),(1,2,0))
                
                img_0 *= 1.0/img_0.max() #Normalize to rgb range
                
                show_images([img_0,img_1], cols = 1, titles = ["generated","target"])
#                 fig = plt.figure()
#                 plt.subplot(111)
#                 plt.imshow(np.transpose(imgs_numpy[0],(1,2,0)),aspect = 'auto')
#                 plt.subplot(211)
#                 plt.imshow(np.transpose(x[0][0],(1,2,0)),aspect = 'auto')
#                 plt.show()
                print()
                plt.gcf().clear()
            iter_count += 1

# %% [markdown]
# ## Experiments

# %%
##Experiment 1 

##Train DCGAN model developed above using regular discriminator and generator Loss 

D_DC = dc_discriminator().type(dtype) 
D_DC.apply(initialize_weights)
G_DC = dc_generator().type(dtype)
G_DC.apply(initialize_weights)

D_DC_solver = get_optimizer(D_DC)
G_DC_solver = get_optimizer(G_DC)

run_gan(D_DC, G_DC, D_DC_solver, G_DC_solver, discriminator_loss, generator_loss, num_epochs=1000,show_every = 1000)

torch.save(D_DC, "./../Models/DCGAN/Discrim")
torch.save(G_DC,"./../Models/DCGAN/Gen")

# %%
#Experiment 2 
#Train DCGANs described above using Least Squares Loss 

D_DC_2 = dc_discriminator().type(dtype) 
D_DC_2.apply(initialize_weights)
G_DC_2 = dc_generator().type(dtype)
G_DC_2.apply(initialize_weights)

D_DC_2_solver = get_optimizer(D_DC_2)
G_DC_2_solver = get_optimizer(G_DC_2)
run_gan(D_DC_2, G_DC_2, D_DC_2_solver, G_DC_2_solver, 
        ls_discriminator_loss, ls_generator_loss, num_epochs=250,show_every = 200)

# %% [markdown]
# # Overfit test

# %%
def run_gan_overfit(D,G,D_solver,G_solver,
            discriminator_loss,generator_loss,
            show_every = 100, batch_size = BATCH_SIZE,
            noise_size = 96,num_epochs = 5):

    iter_count = 0
    for epoch in range(num_epochs):
            x = sphere_model_batch(1,batch_size=batch_size)
            if x[0].shape[0] != batch_size:
                continue
            D_solver.zero_grad()
            real_data = x[0].type(dtype)
            logits_real = D(2* (real_data - 0.5)).type(dtype)

            g_fake_seed = x[1].type(dtype)
            fake_images = G(g_fake_seed).detach()
            
            logits_fake = D(fake_images)
            
            d_total_error = discriminator_loss(logits_real, logits_fake)
            d_total_error.backward()        
            D_solver.step()

            G_solver.zero_grad()
            g_fake_seed = x[1].type(dtype)
            fake_images = G(g_fake_seed)

            gen_logits_fake = D(fake_images)
            g_error = generator_loss(gen_logits_fake)
            g_error.backward()
            G_solver.step()
            
            if (iter_count % show_every == 0):
                print('Iter: {}, D: {:.4}, G:{:.4}'.format(iter_count,d_total_error.item(),g_error.item()))
                imgs_numpy = fake_images.data.cpu().numpy()
                img_0 = np.transpose(imgs_numpy[0],(1,2,0))
                img_1 = np.transpose(x[0][0].numpy(),(1,2,0))
                
                img_0 *= 1.0/img_0.max() #Normalize to rgb range
                
                show_images([img_0,img_1], cols = 1, titles = ["generated","target"])
#                 fig = plt.figure()
#                 plt.subplot(111)
#                 plt.imshow(np.transpose(imgs_numpy[0],(1,2,0)),aspect = 'auto')
#                 plt.subplot(211)
#                 plt.imshow(np.transpose(x[0][0],(1,2,0)),aspect = 'auto')
#                 plt.show()
                print()
                plt.gcf().clear()
            iter_count += 1

# %%
D_DC_3 = dc_discriminator().type(dtype) 
D_DC_3.apply(initialize_weights)
G_DC_3 = dc_generator().type(dtype)
G_DC_3.apply(initialize_weights)
D_DC_3_solver = optim.Adam(D_DC_3.parameters(),lr =1e-3,betas=(0.5,0.999))
G_DC_3_solver = optim.Adam(G_DC_3.parameters(),lr =1e-3,betas=(0.5,0.999))

run_gan_overfit(D_DC_3,
                G_DC_3,
                D_DC_3_solver, G_DC_3_solver,
                discriminator_loss, generator_loss,
                num_epochs=25000,show_every = 1000,batch_size =3)
torch.save(D_DC_3, "./../Models/DCGAN/Discrim_overfit")
torch.save(G_DC_3,"./../Models/DCGAN/Gen_overfit")
# Out:
# /home/arjunarora/anaconda3/envs/cs248/lib/python3.6/site-packages/ipykernel_launcher.py:54: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
# /home/arjunarora/anaconda3/envs/cs248/lib/python3.6/site-packages/ipykernel_launcher.py:28: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Iter: 0, D: 4.35, G:0.669
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Iter: 1000, D: 2.138, G:0.8243
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Iter: 2000, D: 0.01874, G:3.991
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Iter: 3000, D: 0.004583, G:5.391
# ...
